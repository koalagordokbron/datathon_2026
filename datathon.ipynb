# %%
import pandas as pd

# %%
raw_df = pd.read_csv('location.csv')
meteo_df = pd.read_csv('open_meteo.csv')

# %%
display(raw_df)
# Out:
#     location_id   latitude  longitude  elevation  utc_offset_seconds  \
# 0             0  42.847100  -2.666657      546.0                3600
# 1             1  38.980667  -1.849304      690.0                3600
# 2             2  38.347977  -0.487152       19.0                3600
# 3             3  36.871704  -2.486847        5.0                3600
# 4             4  43.339190  -5.793426      245.0                3600
# 5             5  40.667835  -4.716736     1122.0                3600
# 6             6  38.840070  -7.008179      195.0                3600
# 7             7  41.441124   2.201439       28.0                3600
# 8             8  42.355007  -3.695038      858.0                3600
# 9             9  39.472760  -6.348541      442.0                3600
# 10           10  36.590508  -6.243439       25.0                3600
# 11           11  43.409490  -3.778107       12.0                3600
# 12           12  39.964848   0.000000       45.0                3600
# ...

# %%
display(meteo_df)
# Out:
#         location_id              time  temperature_2m (°C)  cloud_cover (%)  \
# 0                 0  2024-01-01T00:00                  3.2              100
# 1                 0  2024-01-01T01:00                  4.0              100
# 2                 0  2024-01-01T02:00                  4.0              100
# 3                 0  2024-01-01T03:00                  3.8              100
# 4                 0  2024-01-01T04:00                  3.3              100
# ...             ...               ...                  ...              ...
# 412843           46  2024-12-31T19:00                  2.1               17
# 412844           46  2024-12-31T20:00                  1.5               16
# 412845           46  2024-12-31T21:00                  0.6               13
# 412846           46  2024-12-31T22:00                  0.1               16
# 412847           46  2024-12-31T23:00                 -0.1               30
#
# ...
